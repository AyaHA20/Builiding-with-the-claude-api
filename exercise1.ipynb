# %%
#load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an api client 

from anthropic import Anthropic

client=Anthropic()
model="claude-sonnet-4-6"

# %%
def add_user_message(messages,text):
  user_message ={"role": "user", "content":text}
  messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
  params= {
     "model":model,
     "max_tokens":1000,
     "messages":messages,
     "temperature":temperature
  }
  if system:
     params["system"]=system
  message = client.messages.create(**params)
  return message.content[0].text

# %%
#make initial list of messages
messages =[]
#use a 'while true ' loop to run the chatbot forever 
while True :
  #get user input
  user_input= input(">")
  print(">",user_input)
  # add user input to the list of messages
  add_user_message(messages, user_input)
  #call claude code with the 'chat' function 
  answer=chat(messages)
  #add generated text to the list of messages 
  add_assistant_message(messages, answer)
  #print the generated text 
  print("---")
  print(answer)
  print("---")
# Out:
# > what's 1+1
# ---
# 1 + 1 = **2**
# ---
# > and if i want add 5 to  it
# ---
# If you add 5 to the result (2 + 5), you get **7**!
# ---
# > okay and what lily means
# ---
# The name **Lily** has several meanings:
#
# - 🌸 **Flower** - It is derived from the **lily flower**, which is a beautiful flowering plant
# - **Purity** - The lily flower is often associated with **purity and innocence**
# - **Beauty** - It also symbolizes **beauty and elegance**
# - **Rebirth** - In some cultures, it represents **rebirth and renewal**
#
# It is a popular **girl's name** and also simply the name of the **lily flower**! 🌷
# ---

# %%
messages = []
#system ="""
#i want u to give a respond that is clean and short as it can be 
#"""
add_user_message(messages,"generate one sentence movie idea")
answer=chat(messages, temperature=0.0)
answer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2 #system ="""
#       3 #i want u to give a respond that is clean and short as it can be
#       4 #"""
#       5 add_user_message(messages,"generate one sentence movie idea")
# ----> 6 answer=chat(messages, temperature=0.0)
#       7 answer
#
# Cell In[7], line 18, in chat(messages, system, temperature)
#      14      "temperature":temperature
#      15   }
#      16   if system:
#      17      params["system"]=system
# ---> 18   message = client.messages.create(**params)
#      19   return message.content[0].text
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# TypeError: Messages.create() got an unexpected keyword argument 'temperature'
